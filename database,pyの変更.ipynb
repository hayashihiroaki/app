# %%
from assets import models
import pandas as pd

from assets.database import db_session

# %%
df= pd.read_csv('assets/data.csv')

# %%
df.head()
# Out:
#         date  subscribers  reviews
# 0  2019/1/17         2671      194
# 1  2019/1/18         2671      195
# 2  2019/1/19         2674      197
# 3  2019/1/20         2685      199
# 4  2019/1/21         2695      199

# %%
df.iloc[0,0]
# Out:
# '2019/1/17'

# %%
import datetime

# %%
date=datetime.datetime.strptime(df.iloc[0,0],'%Y/%m/%d').date()
date
# Out:
# datetime.date(2019, 1, 17)

# %%
for index,_df in df.iterrows():
    date=datetime.datetime.strptime(_df['date'],'%Y/%m/%d').date()
    row=models.Data(date=date,subscribers=_df['subscribers'],reviews=_df['reviews'])
    db_session.add(row)
db_session.commit()
# Out:
# 2020-12-02 18:07:03,066 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-12-02 18:07:03,066 INFO sqlalchemy.engine.base.Engine ()
# 2020-12-02 18:07:03,067 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-12-02 18:07:03,067 INFO sqlalchemy.engine.base.Engine ()
# 2020-12-02 18:07:03,068 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-12-02 18:07:03,073 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,073 INFO sqlalchemy.engine.base.Engine ('2019-01-17', 2671, 194, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,075 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,076 INFO sqlalchemy.engine.base.Engine ('2019-01-18', 2671, 195, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,077 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,077 INFO sqlalchemy.engine.base.Engine ('2019-01-19', 2674, 197, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,078 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,079 INFO sqlalchemy.engine.base.Engine ('2019-01-20', 2685, 199, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,079 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,080 INFO sqlalchemy.engine.base.Engine ('2019-01-21', 2695, 199, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,080 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,081 INFO sqlalchemy.engine.base.Engine ('2019-01-22', 2701, 200, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,082 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,082 INFO sqlalchemy.engine.base.Engine ('2019-01-23', 2710, 200, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,083 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,083 INFO sqlalchemy.engine.base.Engine ('2019-01-24', 2718, 201, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,084 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,085 INFO sqlalchemy.engine.base.Engine ('2019-01-25', 2722, 201, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,085 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,086 INFO sqlalchemy.engine.base.Engine ('2019-01-26', 2725, 201, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,087 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,087 INFO sqlalchemy.engine.base.Engine ('2019-01-27', 2734, 202, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,088 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,089 INFO sqlalchemy.engine.base.Engine ('2019-01-28', 2753, 204, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,089 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,090 INFO sqlalchemy.engine.base.Engine ('2019-01-29', 2773, 206, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,091 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,091 INFO sqlalchemy.engine.base.Engine ('2019-01-30', 2785, 208, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,093 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,093 INFO sqlalchemy.engine.base.Engine ('2019-01-31', 2803, 210, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,094 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,095 INFO sqlalchemy.engine.base.Engine ('2019-02-01', 2845, 211, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,096 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,096 INFO sqlalchemy.engine.base.Engine ('2019-02-02', 2847, 213, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,097 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,097 INFO sqlalchemy.engine.base.Engine ('2019-02-03', 2847, 213, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,098 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,099 INFO sqlalchemy.engine.base.Engine ('2019-02-04', 2851, 217, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,099 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,100 INFO sqlalchemy.engine.base.Engine ('2019-02-05', 2852, 218, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,101 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,101 INFO sqlalchemy.engine.base.Engine ('2019-02-06', 2857, 219, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,102 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,102 INFO sqlalchemy.engine.base.Engine ('2019-02-07', 2861, 220, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,103 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,103 INFO sqlalchemy.engine.base.Engine ('2019-02-08', 2865, 222, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,104 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,105 INFO sqlalchemy.engine.base.Engine ('2019-02-09', 2870, 224, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,105 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,106 INFO sqlalchemy.engine.base.Engine ('2019-02-10', 2875, 224, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,107 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,107 INFO sqlalchemy.engine.base.Engine ('2019-02-11', 2892, 227, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,108 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,109 INFO sqlalchemy.engine.base.Engine ('2019-02-12', 2906, 229, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,110 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,111 INFO sqlalchemy.engine.base.Engine ('2019-02-13', 2919, 229, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,111 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,112 INFO sqlalchemy.engine.base.Engine ('2019-02-14', 2942, 231, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,113 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,114 INFO sqlalchemy.engine.base.Engine ('2019-02-15', 2974, 232, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,115 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,116 INFO sqlalchemy.engine.base.Engine ('2019-02-16', 2977, 234, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,117 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,117 INFO sqlalchemy.engine.base.Engine ('2019-02-17', 2978, 234, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,118 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,119 INFO sqlalchemy.engine.base.Engine ('2019-02-18', 2981, 234, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,119 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,120 INFO sqlalchemy.engine.base.Engine ('2019-02-19', 2983, 234, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,121 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,122 INFO sqlalchemy.engine.base.Engine ('2019-02-20', 2984, 237, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,122 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,123 INFO sqlalchemy.engine.base.Engine ('2019-02-21', 2987, 239, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,124 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,124 INFO sqlalchemy.engine.base.Engine ('2019-02-22', 2989, 239, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,126 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,126 INFO sqlalchemy.engine.base.Engine ('2019-02-23', 2993, 241, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,128 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,128 INFO sqlalchemy.engine.base.Engine ('2019-02-24', 2995, 241, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,129 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,130 INFO sqlalchemy.engine.base.Engine ('2019-02-25', 3009, 241, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,130 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,131 INFO sqlalchemy.engine.base.Engine ('2019-02-26', 3014, 243, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,131 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,132 INFO sqlalchemy.engine.base.Engine ('2019-02-27', 3023, 243, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,133 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,133 INFO sqlalchemy.engine.base.Engine ('2019-02-28', 3031, 243, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,134 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,134 INFO sqlalchemy.engine.base.Engine ('2019-03-01', 3052, 244, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,135 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,136 INFO sqlalchemy.engine.base.Engine ('2019-03-02', 3060, 245, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,136 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,137 INFO sqlalchemy.engine.base.Engine ('2019-03-03', 3062, 246, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,138 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,138 INFO sqlalchemy.engine.base.Engine ('2019-03-04', 3063, 249, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,139 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,140 INFO sqlalchemy.engine.base.Engine ('2019-03-05', 3066, 252, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,140 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,141 INFO sqlalchemy.engine.base.Engine ('2019-03-06', 3071, 254, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,142 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,143 INFO sqlalchemy.engine.base.Engine ('2019-03-07', 3074, 255, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,143 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,144 INFO sqlalchemy.engine.base.Engine ('2019-03-08', 3076, 256, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,145 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,145 INFO sqlalchemy.engine.base.Engine ('2019-03-09', 3077, 258, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,146 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,147 INFO sqlalchemy.engine.base.Engine ('2019-03-10', 3080, 258, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,148 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,148 INFO sqlalchemy.engine.base.Engine ('2019-03-11', 3087, 261, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,149 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,150 INFO sqlalchemy.engine.base.Engine ('2019-03-12', 3089, 261, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,151 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,151 INFO sqlalchemy.engine.base.Engine ('2019-03-13', 3093, 262, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,152 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,153 INFO sqlalchemy.engine.base.Engine ('2019-03-14', 3098, 262, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,154 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,154 INFO sqlalchemy.engine.base.Engine ('2019-03-15', 3104, 262, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,155 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,156 INFO sqlalchemy.engine.base.Engine ('2019-03-16', 3112, 262, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,156 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,157 INFO sqlalchemy.engine.base.Engine ('2019-03-17', 3120, 262, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,158 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,159 INFO sqlalchemy.engine.base.Engine ('2019-03-18', 3131, 265, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,160 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,160 INFO sqlalchemy.engine.base.Engine ('2019-03-19', 3142, 266, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,161 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,162 INFO sqlalchemy.engine.base.Engine ('2019-03-20', 3162, 266, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,164 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,164 INFO sqlalchemy.engine.base.Engine ('2019-03-21', 3173, 268, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,165 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,166 INFO sqlalchemy.engine.base.Engine ('2019-03-22', 3180, 269, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,167 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,168 INFO sqlalchemy.engine.base.Engine ('2019-03-23', 3187, 271, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,169 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,170 INFO sqlalchemy.engine.base.Engine ('2019-03-24', 3189, 271, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,171 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,172 INFO sqlalchemy.engine.base.Engine ('2019-03-25', 3196, 274, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,172 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,173 INFO sqlalchemy.engine.base.Engine ('2019-03-26', 3212, 274, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,174 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,174 INFO sqlalchemy.engine.base.Engine ('2019-03-27', 3220, 274, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,175 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,176 INFO sqlalchemy.engine.base.Engine ('2019-03-28', 3226, 275, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,176 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,177 INFO sqlalchemy.engine.base.Engine ('2019-03-29', 3241, 275, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,178 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,178 INFO sqlalchemy.engine.base.Engine ('2019-03-30', 3253, 278, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,179 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,180 INFO sqlalchemy.engine.base.Engine ('2019-03-31', 3255, 278, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,180 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,181 INFO sqlalchemy.engine.base.Engine ('2019-04-01', 3258, 280, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,182 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,182 INFO sqlalchemy.engine.base.Engine ('2019-04-02', 3262, 282, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,183 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,184 INFO sqlalchemy.engine.base.Engine ('2019-04-03', 3264, 282, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,184 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,185 INFO sqlalchemy.engine.base.Engine ('2019-04-04', 3272, 282, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,185 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,186 INFO sqlalchemy.engine.base.Engine ('2019-04-05', 3275, 284, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,187 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,187 INFO sqlalchemy.engine.base.Engine ('2019-04-06', 3276, 287, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,188 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,189 INFO sqlalchemy.engine.base.Engine ('2019-04-07', 3279, 289, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,189 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,190 INFO sqlalchemy.engine.base.Engine ('2019-04-08', 3285, 289, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,191 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,191 INFO sqlalchemy.engine.base.Engine ('2019-04-09', 3300, 291, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,192 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,192 INFO sqlalchemy.engine.base.Engine ('2019-04-10', 3306, 293, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,193 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,194 INFO sqlalchemy.engine.base.Engine ('2019-04-11', 3312, 295, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,195 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,196 INFO sqlalchemy.engine.base.Engine ('2019-04-12', 3319, 295, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,197 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,198 INFO sqlalchemy.engine.base.Engine ('2019-04-13', 3324, 295, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,200 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,202 INFO sqlalchemy.engine.base.Engine ('2019-04-14', 3325, 297, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,203 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,203 INFO sqlalchemy.engine.base.Engine ('2019-04-15', 3329, 298, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,205 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,206 INFO sqlalchemy.engine.base.Engine ('2019-04-16', 3331, 299, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,208 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,210 INFO sqlalchemy.engine.base.Engine ('2019-04-17', 3332, 299, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,212 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,213 INFO sqlalchemy.engine.base.Engine ('2019-04-18', 3333, 299, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,214 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,215 INFO sqlalchemy.engine.base.Engine ('2019-04-19', 3336, 299, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,217 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,217 INFO sqlalchemy.engine.base.Engine ('2019-04-20', 3339, 299, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,218 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,219 INFO sqlalchemy.engine.base.Engine ('2019-04-21', 3343, 300, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,220 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,221 INFO sqlalchemy.engine.base.Engine ('2019-04-22', 3349, 302, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,222 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,223 INFO sqlalchemy.engine.base.Engine ('2019-04-23', 3357, 303, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,225 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,225 INFO sqlalchemy.engine.base.Engine ('2019-04-24', 3370, 303, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,226 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,227 INFO sqlalchemy.engine.base.Engine ('2019-04-25', 3388, 304, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,228 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,229 INFO sqlalchemy.engine.base.Engine ('2019-04-26', 3412, 304, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,229 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,230 INFO sqlalchemy.engine.base.Engine ('2019-04-27', 3437, 305, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,231 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,232 INFO sqlalchemy.engine.base.Engine ('2019-04-28', 3439, 305, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,233 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,233 INFO sqlalchemy.engine.base.Engine ('2019-04-29', 3440, 308, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,234 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,235 INFO sqlalchemy.engine.base.Engine ('2019-04-30', 3447, 309, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,236 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,236 INFO sqlalchemy.engine.base.Engine ('2019-05-01', 3466, 310, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,237 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,238 INFO sqlalchemy.engine.base.Engine ('2019-05-02', 3481, 311, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,239 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,239 INFO sqlalchemy.engine.base.Engine ('2019-05-03', 3504, 314, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,240 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,241 INFO sqlalchemy.engine.base.Engine ('2019-05-04', 3522, 317, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,242 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,242 INFO sqlalchemy.engine.base.Engine ('2019-05-05', 3527, 322, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,244 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,244 INFO sqlalchemy.engine.base.Engine ('2019-05-06', 3533, 324, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,246 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,246 INFO sqlalchemy.engine.base.Engine ('2019-05-07', 3543, 327, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,247 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,248 INFO sqlalchemy.engine.base.Engine ('2019-05-08', 3546, 328, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,249 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,249 INFO sqlalchemy.engine.base.Engine ('2019-05-09', 3555, 330, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,250 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,251 INFO sqlalchemy.engine.base.Engine ('2019-05-10', 3566, 332, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,251 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,252 INFO sqlalchemy.engine.base.Engine ('2019-05-11', 3583, 334, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,253 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,253 INFO sqlalchemy.engine.base.Engine ('2019-05-12', 3594, 335, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,254 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,254 INFO sqlalchemy.engine.base.Engine ('2019-05-13', 3614, 338, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,255 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,256 INFO sqlalchemy.engine.base.Engine ('2019-05-14', 3633, 340, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,257 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,257 INFO sqlalchemy.engine.base.Engine ('2019-05-15', 3647, 344, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,258 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,259 INFO sqlalchemy.engine.base.Engine ('2019-05-16', 3648, 349, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,260 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,261 INFO sqlalchemy.engine.base.Engine ('2019-05-17', 3649, 349, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,262 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,262 INFO sqlalchemy.engine.base.Engine ('2019-05-18', 3651, 351, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,264 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,264 INFO sqlalchemy.engine.base.Engine ('2019-05-19', 3654, 351, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,265 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,266 INFO sqlalchemy.engine.base.Engine ('2019-05-20', 3658, 354, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,267 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,267 INFO sqlalchemy.engine.base.Engine ('2019-05-21', 3671, 354, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,268 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,269 INFO sqlalchemy.engine.base.Engine ('2019-05-22', 3675, 359, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,270 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,270 INFO sqlalchemy.engine.base.Engine ('2019-05-23', 3681, 359, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,271 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,272 INFO sqlalchemy.engine.base.Engine ('2019-05-24', 3694, 361, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,273 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,273 INFO sqlalchemy.engine.base.Engine ('2019-05-25', 3699, 361, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,274 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,275 INFO sqlalchemy.engine.base.Engine ('2019-05-26', 3711, 364, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,276 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,277 INFO sqlalchemy.engine.base.Engine ('2019-05-27', 3722, 368, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,278 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,278 INFO sqlalchemy.engine.base.Engine ('2019-05-28', 3734, 373, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,279 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,280 INFO sqlalchemy.engine.base.Engine ('2019-05-29', 3766, 374, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,280 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,281 INFO sqlalchemy.engine.base.Engine ('2019-05-30', 3781, 375, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,282 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,282 INFO sqlalchemy.engine.base.Engine ('2019-05-31', 3784, 375, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,283 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,284 INFO sqlalchemy.engine.base.Engine ('2019-06-01', 3789, 378, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,285 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,285 INFO sqlalchemy.engine.base.Engine ('2019-06-02', 3790, 379, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,286 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,287 INFO sqlalchemy.engine.base.Engine ('2019-06-03', 3793, 380, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,288 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,288 INFO sqlalchemy.engine.base.Engine ('2019-06-04', 3795, 383, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,289 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,290 INFO sqlalchemy.engine.base.Engine ('2019-06-05', 3808, 385, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,291 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,291 INFO sqlalchemy.engine.base.Engine ('2019-06-06', 3830, 386, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,292 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,293 INFO sqlalchemy.engine.base.Engine ('2019-06-07', 3843, 387, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,294 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,295 INFO sqlalchemy.engine.base.Engine ('2019-06-08', 3857, 390, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,296 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,296 INFO sqlalchemy.engine.base.Engine ('2019-06-09', 3870, 394, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,297 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,298 INFO sqlalchemy.engine.base.Engine ('2019-06-10', 3895, 395, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,299 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,299 INFO sqlalchemy.engine.base.Engine ('2019-06-11', 3919, 397, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,300 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,300 INFO sqlalchemy.engine.base.Engine ('2019-06-12', 3942, 399, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,301 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,302 INFO sqlalchemy.engine.base.Engine ('2019-06-13', 3983, 402, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,302 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,303 INFO sqlalchemy.engine.base.Engine ('2019-06-14', 4022, 404, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,303 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,304 INFO sqlalchemy.engine.base.Engine ('2019-06-15', 4053, 409, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,305 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,305 INFO sqlalchemy.engine.base.Engine ('2019-06-16', 4058, 410, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,306 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,306 INFO sqlalchemy.engine.base.Engine ('2019-06-17', 4063, 414, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,307 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,308 INFO sqlalchemy.engine.base.Engine ('2019-06-18', 4064, 417, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,309 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,309 INFO sqlalchemy.engine.base.Engine ('2019-06-19', 4065, 422, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,310 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,311 INFO sqlalchemy.engine.base.Engine ('2019-06-20', 4066, 424, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,312 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,312 INFO sqlalchemy.engine.base.Engine ('2019-06-21', 4069, 425, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,313 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,314 INFO sqlalchemy.engine.base.Engine ('2019-06-22', 4070, 426, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,314 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,315 INFO sqlalchemy.engine.base.Engine ('2019-06-23', 4073, 427, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,316 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,316 INFO sqlalchemy.engine.base.Engine ('2019-06-24', 4084, 427, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,317 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,317 INFO sqlalchemy.engine.base.Engine ('2019-06-25', 4108, 427, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,318 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,319 INFO sqlalchemy.engine.base.Engine ('2019-06-26', 4122, 433, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,319 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,320 INFO sqlalchemy.engine.base.Engine ('2019-06-27', 4132, 436, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,321 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,321 INFO sqlalchemy.engine.base.Engine ('2019-06-28', 4150, 440, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,322 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,322 INFO sqlalchemy.engine.base.Engine ('2019-06-29', 4162, 440, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,323 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,323 INFO sqlalchemy.engine.base.Engine ('2019-06-30', 4164, 446, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,324 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,325 INFO sqlalchemy.engine.base.Engine ('2019-07-01', 4167, 448, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,326 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,326 INFO sqlalchemy.engine.base.Engine ('2019-07-02', 4174, 450, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,327 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,328 INFO sqlalchemy.engine.base.Engine ('2019-07-03', 4179, 455, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,329 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,329 INFO sqlalchemy.engine.base.Engine ('2019-07-04', 4187, 456, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,330 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,331 INFO sqlalchemy.engine.base.Engine ('2019-07-05', 4200, 456, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,331 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,332 INFO sqlalchemy.engine.base.Engine ('2019-07-06', 4210, 458, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,333 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,333 INFO sqlalchemy.engine.base.Engine ('2019-07-07', 4211, 458, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,334 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,334 INFO sqlalchemy.engine.base.Engine ('2019-07-08', 4214, 464, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,335 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,335 INFO sqlalchemy.engine.base.Engine ('2019-07-09', 4219, 464, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,336 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,337 INFO sqlalchemy.engine.base.Engine ('2019-07-10', 4223, 468, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,337 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,338 INFO sqlalchemy.engine.base.Engine ('2019-07-11', 4228, 469, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,339 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,339 INFO sqlalchemy.engine.base.Engine ('2019-07-12', 4236, 469, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,340 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,340 INFO sqlalchemy.engine.base.Engine ('2019-07-13', 4239, 471, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,341 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,342 INFO sqlalchemy.engine.base.Engine ('2019-07-14', 4243, 471, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,343 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,344 INFO sqlalchemy.engine.base.Engine ('2019-07-15', 4250, 473, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,344 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,345 INFO sqlalchemy.engine.base.Engine ('2019-07-16', 4265, 476, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,346 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,346 INFO sqlalchemy.engine.base.Engine ('2019-07-17', 4288, 476, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,347 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,348 INFO sqlalchemy.engine.base.Engine ('2019-07-18', 4313, 483, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,349 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,349 INFO sqlalchemy.engine.base.Engine ('2019-07-19', 4329, 483, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,350 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,350 INFO sqlalchemy.engine.base.Engine ('2019-07-20', 4329, 486, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,351 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,352 INFO sqlalchemy.engine.base.Engine ('2019-07-21', 4329, 487, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,352 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,353 INFO sqlalchemy.engine.base.Engine ('2019-07-22', 4333, 492, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,354 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,354 INFO sqlalchemy.engine.base.Engine ('2019-07-23', 4335, 493, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:03,355 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:03,355 INFO sqlalchemy.engine.base.Engine ('2019-07-24', 4353, 494, '2020-12-02 17:51:17.437401')
# ...
# 2020-12-02 18:07:04,140 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,140 INFO sqlalchemy.engine.base.Engine ('2020-09-29', 9100, 1502, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,141 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,142 INFO sqlalchemy.engine.base.Engine ('2020-09-30', 9111, 1505, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,143 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,143 INFO sqlalchemy.engine.base.Engine ('2020-10-01', 9127, 1507, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,144 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,145 INFO sqlalchemy.engine.base.Engine ('2020-10-02', 9140, 1515, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,146 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,146 INFO sqlalchemy.engine.base.Engine ('2020-10-03', 9142, 1516, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,147 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,148 INFO sqlalchemy.engine.base.Engine ('2020-10-04', 9151, 1517, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,148 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,149 INFO sqlalchemy.engine.base.Engine ('2020-10-05', 9156, 1518, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,150 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,150 INFO sqlalchemy.engine.base.Engine ('2020-10-06', 9170, 1519, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,151 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,151 INFO sqlalchemy.engine.base.Engine ('2020-10-07', 9190, 1521, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,152 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,153 INFO sqlalchemy.engine.base.Engine ('2020-10-08', 9194, 1522, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,153 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,154 INFO sqlalchemy.engine.base.Engine ('2020-10-09', 9197, 1526, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,155 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,155 INFO sqlalchemy.engine.base.Engine ('2020-10-10', 9200, 1526, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,156 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,156 INFO sqlalchemy.engine.base.Engine ('2020-10-11', 9204, 1528, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,157 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,157 INFO sqlalchemy.engine.base.Engine ('2020-10-12', 9214, 1531, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,159 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,159 INFO sqlalchemy.engine.base.Engine ('2020-10-13', 9220, 1536, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,160 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,161 INFO sqlalchemy.engine.base.Engine ('2020-10-14', 9248, 1540, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,162 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,162 INFO sqlalchemy.engine.base.Engine ('2020-10-15', 9265, 1540, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,163 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,164 INFO sqlalchemy.engine.base.Engine ('2020-10-16', 9297, 1542, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,164 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,165 INFO sqlalchemy.engine.base.Engine ('2020-10-17', 9300, 1546, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,166 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,166 INFO sqlalchemy.engine.base.Engine ('2020-10-18', 9308, 1547, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,167 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,167 INFO sqlalchemy.engine.base.Engine ('2020-10-19', 9314, 1549, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,168 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,169 INFO sqlalchemy.engine.base.Engine ('2020-10-20', 9322, 1552, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,169 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,170 INFO sqlalchemy.engine.base.Engine ('2020-10-21', 9335, 1554, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,171 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,171 INFO sqlalchemy.engine.base.Engine ('2020-10-22', 9353, 1556, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,172 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,172 INFO sqlalchemy.engine.base.Engine ('2020-10-23', 9362, 1560, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,173 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,173 INFO sqlalchemy.engine.base.Engine ('2020-10-24', 9363, 1563, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,174 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,175 INFO sqlalchemy.engine.base.Engine ('2020-10-25', 9371, 1563, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,176 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,176 INFO sqlalchemy.engine.base.Engine ('2020-10-26', 9378, 1565, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,177 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,178 INFO sqlalchemy.engine.base.Engine ('2020-10-27', 9395, 1566, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,179 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,179 INFO sqlalchemy.engine.base.Engine ('2020-10-28', 9417, 1567, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,180 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,180 INFO sqlalchemy.engine.base.Engine ('2020-10-29', 9437, 1569, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,181 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,182 INFO sqlalchemy.engine.base.Engine ('2020-10-30', 9457, 1571, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,182 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,183 INFO sqlalchemy.engine.base.Engine ('2020-10-31', 9462, 1575, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,184 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,184 INFO sqlalchemy.engine.base.Engine ('2020-11-01', 9465, 1576, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,185 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,186 INFO sqlalchemy.engine.base.Engine ('2020-11-02', 9465, 1578, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,186 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,187 INFO sqlalchemy.engine.base.Engine ('2020-11-03', 9469, 1578, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,188 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,188 INFO sqlalchemy.engine.base.Engine ('2020-11-04', 9476, 1579, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,189 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,189 INFO sqlalchemy.engine.base.Engine ('2020-11-05', 9481, 1581, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,190 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,190 INFO sqlalchemy.engine.base.Engine ('2020-11-06', 9484, 1587, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,191 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,192 INFO sqlalchemy.engine.base.Engine ('2020-11-07', 9491, 1589, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,193 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,193 INFO sqlalchemy.engine.base.Engine ('2020-11-08', 9493, 1592, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,194 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,195 INFO sqlalchemy.engine.base.Engine ('2020-11-09', 9497, 1593, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,196 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,196 INFO sqlalchemy.engine.base.Engine ('2020-11-10', 9501, 1594, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,197 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,198 INFO sqlalchemy.engine.base.Engine ('2020-11-11', 9507, 1595, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,198 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,199 INFO sqlalchemy.engine.base.Engine ('2020-11-12', 9544, 1597, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,200 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,200 INFO sqlalchemy.engine.base.Engine ('2020-11-13', 9551, 1599, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,201 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,201 INFO sqlalchemy.engine.base.Engine ('2020-11-14', 9556, 1603, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,202 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,203 INFO sqlalchemy.engine.base.Engine ('2020-11-15', 9563, 1605, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,203 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,204 INFO sqlalchemy.engine.base.Engine ('2020-11-16', 9565, 1606, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,205 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,205 INFO sqlalchemy.engine.base.Engine ('2020-11-17', 9569, 1608, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,206 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,206 INFO sqlalchemy.engine.base.Engine ('2020-11-18', 9581, 1613, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,207 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,208 INFO sqlalchemy.engine.base.Engine ('2020-11-19', 9583, 1613, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,209 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,210 INFO sqlalchemy.engine.base.Engine ('2020-11-20', 9585, 1614, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,211 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,212 INFO sqlalchemy.engine.base.Engine ('2020-11-21', 9611, 1618, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,213 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,213 INFO sqlalchemy.engine.base.Engine ('2020-11-22', 9647, 1618, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,214 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,215 INFO sqlalchemy.engine.base.Engine ('2020-11-23', 9681, 1618, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,215 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,216 INFO sqlalchemy.engine.base.Engine ('2020-11-24', 9708, 1618, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,217 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,217 INFO sqlalchemy.engine.base.Engine ('2020-11-25', 9733, 1618, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,218 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,218 INFO sqlalchemy.engine.base.Engine ('2020-11-26', 9769, 1618, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,219 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,220 INFO sqlalchemy.engine.base.Engine ('2020-11-27', 9838, 1618, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,220 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,221 INFO sqlalchemy.engine.base.Engine ('2020-11-28', 9926, 1618, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,222 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,222 INFO sqlalchemy.engine.base.Engine ('2020-11-29', 9932, 1618, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,223 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-12-02 18:07:04,223 INFO sqlalchemy.engine.base.Engine ('2020-12-02', 10003, 1658, '2020-12-02 17:51:17.437401')
# 2020-12-02 18:07:04,233 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
def read_data():
    from assets import models
    df= pd.read_csv('assets/data.csv')
    for index,_df in df.iterrows():
        date=datetime.datetime.strptime(_df['date'],'%Y/%m/%d').date()
        row=models.Data(date=date,subscribers=_df['subscribers'],reviews=_df['reviews'])
        db_session.add(row)
    db_session.commit()
